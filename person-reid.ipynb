# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# ===== Cell 1 =====
# Clone repo
! git clone https://github.com/Debjit-Dhar/CLIP-ReID.git
! cd CLIP-ReID

# Quick GPU check
! nvidia-smi || echo "no nvidia-smi detected"

# %%
# ===== Cell 2 =====
# Move into repo directory if you are not already in it
! cd /kaggle/working/CLIP-ReID || cd CLIP-ReID

# Install the small Python deps from README
! pip install yacs timm scikit-image tqdm ftfy regex

# Try to install PyTorch 1.8.0 with CUDA 10.2 wheels (may or may not work depending on kernel)
# If it fails, comment it out and try the CPU fallback.
# pip install torch==1.8.0+cu102 torchvision==0.9.0+cu102 torchaudio==0.8.0 -f https://download.pytorch.org/whl/cu102/torch_stable.html || \
#{ echo "GPU wheel install failed. Trying CPU-only torch wheel."; \
#  pip install torch==1.8.0+cpu torchvision==0.9.0+cpu torchaudio==0.8.0 -f https://download.pytorch.org/whl/torch_stable.html; }

# %%
# ===== Cell 3 =====
# Example: list files inside /kaggle/input so you can find dataset and weight names
! ls -la /kaggle/input

# If your Market-1501 in /kaggle/input is named something like market-1501, inspect it:
! ls -la /kaggle/input/market-1501 || true

# %%
# ===== Cell 4 =====
# Run test (exact command you provided)
! export CUDA_VISIBLE_DEVICES=0
! cd '/kaggle/working/CLIP-ReID'
! python /kaggle/working/CLIP-ReID/test_clipreid.py --config_file /kaggle/working/CLIP-ReID/configs/person/vit_clipreid.yml TEST.WEIGHT '/kaggle/input/models/debjitdharcseju/clip-reid-for-market-1501/transformers/default/1/Market1501_clipreid_12x12sie_ViT-B-16_60.pth' MODEL.SIE_CAMERA True MODEL.SIE_COE 1.0 MODEL.STRIDE_SIZE '[12, 12]'
